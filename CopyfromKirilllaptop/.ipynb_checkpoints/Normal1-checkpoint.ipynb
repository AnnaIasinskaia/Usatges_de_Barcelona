# %%
import AnnDiplomMatrix
import latin.LDA
import numpy as np
from scipy.spatial import distance
import time

# %%
def ContextAnalyse(path1, path2, lemma = False):
    #print("Load matrix 1 from file:", path1)
    x = AnnDiplomMatrix.text2matrixNdict(path1, lemma)
    #print("Load matrix 2 from file:", path2)
    y = AnnDiplomMatrix.text2matrixNdict(path2, lemma)
    
    g = list(x.numeratedDict.keys())+list(y.numeratedDict.keys())
    g = list(set(g))
    g.sort()
    max_size = len(g)
    numeratedDict_g = dict(zip(g, range(max_size)))
    new_matrix_x = np.zeros((max_size, max_size))
    new_matrix_y = np.zeros((max_size, max_size))
    start_t = time.clock()
    for i in g:
        
        for j in g:
            #print(i, j)
            if i in x.numeratedDict.keys() and j in x.numeratedDict.keys():
                i_i = x.numeratedDict[i]
                j_j = x.numeratedDict[j]

                new_matrix_x[numeratedDict_g[i], numeratedDict_g[j]] = x.matrix[i_i, j_j]      
    for i in g:

        for j in g:
            #print(i, j)
            if i in y.numeratedDict.keys() and j in y.numeratedDict.keys():
                i_i = y.numeratedDict[i]
                j_j = y.numeratedDict[j]

                new_matrix_y[numeratedDict_g[i], numeratedDict_g[j]] = y.matrix[i_i, j_j]    
    a = new_matrix_x.flatten()
    b = new_matrix_y.flatten()
    return distance.cosine(a, b)

# %%
def FrequencyAnalyse(path1, path2, lemma = False):
    x = AnnDiplomMatrix.text2matrixNdictFreq(path1, lemma)
    y = AnnDiplomMatrix.text2matrixNdictFreq(path2, lemma)
    g = list(x.numeratedDict.keys())+list(y.numeratedDict.keys())
    g = list(set(g))
    g.sort()
    max_size = len(g)
    numeratedDict_g = dict(zip(g, range(max_size)))

    new_matrix_x = np.zeros((max_size))
    new_matrix_y = np.zeros((max_size))

    for i in g:
        #print(i, j)
        if i in x.numeratedDict.keys() and i in x.numeratedDict.keys():
            i_i = x.numeratedDict[i]
            new_matrix_x[numeratedDict_g[i]] = x.matrix[i_i]   
    for i in g:
        #print(i, j)
        if i in y.numeratedDict.keys() and i in y.numeratedDict.keys():
            i_i = y.numeratedDict[i]
            new_matrix_y[numeratedDict_g[i]] = y.matrix[i_i] 

    a = new_matrix_x.flatten()
    b = new_matrix_y.flatten()
    return distance.cosine(a, b)

# %%
#path1 = "Latin.docx"
#path2 = "Этимологии.docx"

#print("Context cosine:", round(ContextAnalyse(path1, path2),4))
#print("Frequency cosine:", round(FrequencyAnalyse(path1, path2),4))

# %%
List_of_cosine = []
List_of_frequency = []
List_of_cosine_stem = []
List_of_frequency_stem = []

path = "Latin.docx"
files2an = [
    "Exeptionis Legum Romanorum Petri.docx",
    "Isidori Hispalensis Episcopi Etymologiarum.docx",
    "Evangelium.docx",
    "Lex Visigothorum.docx",
]
for x in files2an:
    print(x)
    #print("Context cosine calculating")
    C_L = round(ContextAnalyse(path, x, True),4)
    C_S = round(ContextAnalyse(path, x, False),4)
    print("Context cosine:", C_L)
    
    #print("Frequency cosine calculating")
    F_L = round(FrequencyAnalyse(path, x, True),4)
    F_S = round(FrequencyAnalyse(path, x, False),4) 
    print("Frequency cosine:", F_L)
    List_of_cosine.append(C_L)
    List_of_frequency.append(F_L)
    List_of_cosine_stem.append(C_S)
    List_of_frequency_stem.append(F_S)
# Out:
# Exeptionis Legum Romanorum Petri.docx
# Context cosine: 0.6908
# Frequency cosine: 0.8821
# Isidori Hispalensis Episcopi Etymologiarum.docx
# Context cosine: 0.906
# Frequency cosine: 0.872
# Evangelium.docx
# Context cosine: 0.8529
# Frequency cosine: 0.831
# Lex Visigothorum.docx
# Context cosine: 0.7877
# Frequency cosine: 0.8417

# %%
import matplotlib.pyplot as plt

# %%
List_of_cosine
# Out:
# [0.6908, 0.906, 0.8529, 0.7877]

# %%
labels = ['Exeptionis Legum Romanorum Petri','Isidori Hispalensis Episcopi Etymologiarum', 'Evangelium','Lex Visigothorum']

x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars

fig, ax = plt.subplots(figsize=(20, 10))
rects1 = ax.bar(x + 0.0, List_of_cosine, width = 0.2,  label='Cosine_L')
rects2 = ax.bar(x + 0.2, List_of_frequency,  width =  0.2, label='Frequency_L')
rects3 = ax.bar(x + 0.4, List_of_cosine_stem,  width =  0.2, label='Cosine_S')
rects4 = ax.bar(x + 0.6, List_of_frequency_stem, width =  0.2, label='Frequency_S')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Distance')
ax.set_title('The results of the analysis')
ax.set_xticks(x)
fontdict = {'fontsize': 16}
ax.set_xticklabels(labels)
ax.tick_params(axis='both', which='major', labelsize=16)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 4),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

fig.tight_layout()

plt.show()

# %%
path = "Latin.docx"
y = AnnDiplomMatrix.text2matrixNdictFreq(path, True)
L=list(y.numeratedDict.keys())

# %%
y

# %%
import pandas as pd
files2an = [
    "Exeptionis Legum Romanorum Petri.docx",
    "Latin.docx",
    "EVANGELIUM.docx",
    "Isidori Hispalensis Episcopi Etymologiarum.docx",
    "Corpus Juris Civilis.docx",
    "Lex Visigothorum.docx"
]
frames = []
for path in files2an:
    y = AnnDiplomMatrix.text2matrixNdictFreq(path, True)
    L=list(y.numeratedDict.keys())
    df = pd.DataFrame()
    df['word']= L
    df['doc']=[path]*len(L)
    frames.append(df)
df_full=pd.concat(frames)
df_full.to_csv('unified_texts.csv', index=False, header=False)

# %%
configFile = 'config.json'
LDA.main(configFile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-011fce279359> in <module>
#       1 configFile = 'config.json'
# ----> 2 LDA.main(configFile)
#
# NameError: name 'LDA' is not defined

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
